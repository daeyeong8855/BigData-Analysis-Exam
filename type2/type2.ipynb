# %% [markdown]
# # Q1

# %%
import pandas as pd
import kagglehub

# Download latest version
path = kagglehub.dataset_download("agileteam/bigdatacertificationkr")
submit = pd.read_csv(path + "/Customer_Data.csv")
# Out:
# Downloading to C:\Users\daeye\.cache\kagglehub\datasets\agileteam\bigdatacertificationkr\29.archive...
# 100%|██████████| 278k/278k [00:00<00:00, 1.28MB/s]
# Extracting files...
